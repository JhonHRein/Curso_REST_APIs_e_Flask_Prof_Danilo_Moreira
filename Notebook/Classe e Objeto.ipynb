# %%
#Classe é um modelo ou uma representação de um objeto.
#Objeto é uma instancia de uma classe.
#Instancia é um recurso especifico dentro da coleçao, representa um unico item identificador por ID.
# Out:
# True

# %%
class JogadorLoteria:
    def __init__(self, nome):
        self.nome = nome
        self.numeros = (13,4,52,23,67,82)
    
    
    def total(self):
        return sum(self.numeros)


jogador_1 = JogadorLoteria("Ana")
jogador_2 = JogadorLoteria("Felipe")



print(f"- {jogador_1.nome}\n- {jogador_1.numeros}\n- Total da soma: {jogador_1.total()}")
# Out:
# - Ana
# - (13, 4, 52, 23, 67, 82)
# - Total da soma: 241
